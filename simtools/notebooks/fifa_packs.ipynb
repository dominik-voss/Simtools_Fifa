# %%
from pathlib import Path
import sys

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
SRC_DIR = "simtools/src"

if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

from plots_packs_coins import (
    plot_packs_vs_cards,
    plot_coins_vs_cards,
)

# %%
PROJECT_ROOT = Path.cwd().parents[0]   # -> project/
CSV_PATH = PROJECT_ROOT / "reports" / "simulation_results.csv"
FIG_DIR = PROJECT_ROOT / "reports" / "figures"
FIG_DIR.mkdir(parents=True, exist_ok=True)

df_results = pd.read_csv(CSV_PATH)

CSV_PATH, FIG_DIR
# Out:
# (WindowsPath('c:/Users/49159/Desktop/Uni/SDC/WS2526/Simtools/my-python-project/simtools/reports/simulation_results.csv'),
#  WindowsPath('c:/Users/49159/Desktop/Uni/SDC/WS2526/Simtools/my-python-project/simtools/reports/figures'))

# %%
plot_packs_vs_cards(
    csv_path=CSV_PATH,
    output_path=FIG_DIR / "packs_vs_cards.png",
)

plot_coins_vs_cards(
    csv_path=CSV_PATH,
    output_path=FIG_DIR / "coins_vs_cards.png",
    pack_price=7500,
)
# Out:
# Plot saved to: c:\Users\49159\Desktop\Uni\SDC\WS2526\Simtools\my-python-project\simtools\reports\figures\packs_vs_cards.png
# Plot saved to: c:\Users\49159\Desktop\Uni\SDC\WS2526\Simtools\my-python-project\simtools\reports\figures\coins_vs_cards.png

# %%
n_cards = 1900

mask = df_results["total_cards"] == n_cards
expected_packs = float(df_results.loc[mask, "mu"].iloc[0])

coins_cost = expected_packs * 7500
points_cost = expected_packs * 1.25

print(f"Expected packs for {n_cards} cards: {expected_packs:.2f}")
print(f"Total cost: {coins_cost:,.0f} coins")
print(f"Total cost in points/€: {points_cost:,.2f}")
# Out:
# Expected packs for 1900 cards: 31283.57
# Total cost: 234,626,775 coins
# Total cost in points/€: 39,104.46
